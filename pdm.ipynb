# %%
import base64
import zlib
import gzip

# %%
import requests
import matplotlib.pyplot as plt
from owslib.wms import WebMapService
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# WMS endpoint
url = "https://geopdm.cm-porto.pt/services/pdm/wms"

# Connect to the WMS service
wms = WebMapService(url)

# Print available layers
print("Available layers:")
for layer in wms.contents:
    print(layer)
# Out:
# Available layers:
# PDM_1A_PO_CQS
# PDM_2021mai_RDP:RDP_AIPLANO_PL
# PDM_2021mai_RDP:RDP_QSFUNCIONAL_PL
# PDM_2021mai_RDP:RDP_QSOPERATIVA_PL
# PDM_2021mai_RDP:RDP_LINHAS_MERGE
# PDM_2021mai_RDP:RDP_PONTES_LN
# PDM_2021mai_RDP:RDP_RPEDONAL_PL-NC1
# PDM_2021mai_RDP:RDP_CRODOVIARIOS_LN-Proposta
# PDM_2021mai_RDP:RDP_AIPMPPORMENOR_PL
# PDM_2021mai_RDP:RDP_UOPGESTAO_PL
# PDM_1B_PO_CEEM
# PDM_2021mai_RDP:RDP_AVAPUBLICO_PL
# PDM_2021mai_RDP:RDP_AVEVECOLOGICO_PL
# PDM_2021mai_RDP:RDP_AVAZSENSIVEIS_PL
# PDM_2021mai_RDP:RDP_RCONEXAO_PL
# PDM_2021mai_RDP:RDP_CVERDES_PL
# PDM_2021mai_RDP:RDP_AFARIBEIRINHA_PL
# PDM_2021mai_RDP:RDP_ALUVIAO_PL
# PDM_2021mai_RDP:RDP_ADECLIVOSA_PL
# PDM_2021mai_RDP:RDP_LAGUA_LN
# PDM_2021mai_RDP:RDP_BRETENCAO_PT
# PDM_2021mai_RDP:RDP_CECOLOGICO_PL
# PDM_2021mai_RDP:RDP_SRHOMOGENEAS_PL
# PDM_1C_PO_CRN_AA1
# PDM_2021mai_RDP:AA1_APARTIFICIALIZADAS_PL
# PDM_2021mai_RDP:AA1_ZMPROTECAO_PL
# PDM_2021mai_RDP:AA1_ZTPROTECAO_PL
# PDM_2021mai_RDP:AA1_FSGICOSTEIRA_PL
# PDM_2021mai_RDP:AA1_FSECOSTEIRA_PL
# PDM_2021mai_RDP:AA1_PIPMARITIMAS_LN
# PDM_2021mai_RDP:AA1_TPRAIAS_PT
# PDM_2021mai_RDP:AA1_MARGEM_PL
# PDM_2021mai_RDP:AA1_APORTUARIA_LN
# PDM_2021mai_RDP:AA1_LAIPOCCE_LN
# PDM_2021mai_RDP:AA1_ZIPINSTAVEL_PL
# PDM_2021mai_RDP:AA1_AINUNDAVEIS_PL
# PDM_2021mai_RDP:AA1_NPISCATORIO_PT
# PDM_2021mai_RDP:AA1_ACRITICAS_PL
# PDM_1D_PO_CZA
# PDM_2021mai_RDP:RDP_ZACUSTICO_PL
# PDM_1E_PO_CP1
# PDM_2021mai_RDP:RDP_AIUARQUITETONICO_PL
# PDM_2021mai_RDP:RDP_NLUGARES_PL
# PDM_2021mai_RDP:RDP_CIVPATRIMONIAL_PL
# PDM_2021mai_RDP:RDP_ZPICVCLASSIFICACAO_PL
# PDM_2021mai_RDP:RDP_ZNAEDIFICANDI_PL
# PDM_2021mai_RDP:RDP_ZPAAPUBLICO_PL
# PDM_2021mai_RDP:RDP_AAIPUBLICO_PT
# PDM_2021mai_RDP:RDP_PNGCMFDOURO_PL
# PDM_1F_PO_CP2
# PDM_2021mai_RDP:RDP_ASARQUEOLOGICA_PL
# PDM_1G_PO_CEVE
# PDM_2021mai_RDP:RDP_ZCPDLIMITADA_PL
# PDM_2021mai_RDP:RDP_AIEMETRO_PL
# PDM_2021mai_RDP:RDP_EMETRO_PT
# PDM_2021mai_RDP:RDP_CRODOVIARIOS_LN-dif-rua-prov-local_F9
# PDM_2021mai_RDP:RDP_CRODOVIARIOS_LN-dif-rua-prov-local_F8
# PDM_2021mai_RDP:RDP_CRODOVIARIOS_LN-dif-rua-prov-local_F7
# PDM_2021mai_RDP:RDP_CRODOVIARIOS_LN-dif-rua-prov-local_F6
# PDM_2021mai_RDP:RDP_CRODOVIARIOS_LN-dif-rua-prov-local_F5
# PDM_2021mai_RDP:RDP_CRODOVIARIOS_LN-dif-rua-prov-local_F4
# PDM_2021mai_RDP:RDP_CRODOVIARIOS_LN-dif-rua-prov-local_F3
# PDM_2021mai_RDP:RDP_CRODOVIARIOS_LN-dif-rua-prov-local_F2
# PDM_2021mai_RDP:RDP_CRODOVIARIOS_LN-dif-rua-prov-local_F1
# PDM_2B_PC_CPIF
# PDM_2021mai_RDP:RDP_PIFLORESTAL-raw
# PDM_2C_PC_CCGD
# PDM_2021mai_RDP:mvw_m_zsaeronautica_pl
# PDM_2021mai_RDP:mvw_m_pontes_ln
# PDM_2021mai_RDP:vw_m_civpatrimonial_pl
# PDM_2021mai_RDP:mvw_m_dpholagua_pl
# PDM_2021mai_RDP:vw_m_mplavelocidade_pl
# PDM_2021mai_RDP:mvw_m_efprotegidas_pl
# PDM_2021mai_RDP:vw_m_zpaacvclassificacao_pl
# PDM_2021mai_RDP:mvw_m_zsreletrica_pl
# PDM_2021mai_RDP:mvw_m_zpepocipublico_pl
# PDM_2021mai_RDP:mvw_m_dnacional_pl
# PDM_2021mai_RDP:mvw_m_zpetmenores_pl
# PDM_2021mai_RDP:mvw_m_rrnedesclassificadas_pl
# PDM_2021mai_RDP:mvw_m_ideeletrica_ln
# PDM_2021mai_RDP:mvw_m_iteeletrica_ln
# PDM_2021mai_RDP:mvw_m_oleoduto_ln
# PDM_2021mai_RDP:mvw_m_margem_ln
# PDM_2021mai_RDP:mvw_m_fpesada_ln
# PDM_2021mai_RDP:mvw_m_dpferroviario_pl
# PDM_2021mai_RDP:mvw_m_dphidrico_ln
# PDM_2021mai_RDP:mvw_m_zpicvclassificacao_pl
# PDM_2021mai_RDP:mvw_m_znaedificandi_pl
# PDM_2021mai_RDP:mvw_m_itreletrica_pt
# PDM_2021mai_RDP:vw_m_aacvclassificacao_pt
# PDM_2021mai_RDP:mvw_m_fosmaritimo_pt
# PDM_2021mai_RDP:mvw_m_zssmaritima_pl
# PDM_2021mai_RDP:mvw_m_mgeodesicos_pt
# PDM_2021mai_RDP:mvw_m_zprgeodesica_pl
# PDM_2021mai_RDP:mvw_m_zsaagua_pl
# PDM_2021mai_RDP:vw_m_gfdouro_pl
# PDM_4A_CC_CAEC
# PDM_2021mai_RDP:RDP_AECOLETIVOS_PL
# PDM_4B_CC_CITC
# PDM_2021mai_RDP:RDP_INTERFACES_PT
# PDM_2021mai_RDP:RDP_CAUTOCARRO_PL
# PDM_2021mai_RDP:RDP_FULTRALIGEIRA_LN
# PDM_2021mai_RDP:RDP_FPESADA_LN_CC4B_CITC
# PDM_2021mai_RDP:RDP_PDISSUASORES_PT
# PDM_2021mai_RDP:RDP_FLIGEIRA_LN
# PDM_2021mai_RDP:RDP_LBRT_LN
# PDM_2021mai_RDP:RDP_EMETRO_PT_CC4B
# PDM_4C_CC_CIMS
# PDM_2021mai_RDP:RDP_ZXXI_PL
# PDM_2021mai_RDP:RDP_RPEDONAL_PL
# PDM_2021mai_RDP:RDP_RCESTRUTURANTE_PL
# PDM_2021mai_RDP:RDP_IPBICI_LN
# PDM_4D_CC_CI1
# PDM_2021mai_RDP:RDP_ETARS_PL
# PDM_2021mai_RDP:RDP_CTLAREUTILIZACAO_LN
# PDM_2021mai_RDP:RDP_CGIEMISSARIOS_LN
# PDM_2021mai_RDP:RDP_RESERVATORIOS_PL
# PDM_2021mai_RDP:RDP_CADUTORAS_ADP_LN
# PDM_2021mai_RDP:RDP_CADUTORAS_ADDP_LN
# PDM_2021mai_RDP:RDP_PECADUTORAS_ADDP_PT
# PDM_4E_CC_CI2
# PDM_2021mai_RDP:RDP_ITRELETRICA_PL
# PDM_2021mai_RDP:RDP_IDEELETRICA_LN_CC4E
# PDM_2021mai_RDP:RDP_ITEELETRICA_LN_CC4E
# PDM_4F_CC_CI3
# PDM_2021mai_RDP:RDP_ECOCENTROS_PL
# PDM_2021mai_RDP:RDP_OLEODUTO_LN
# PDM_2021mai_RDP:RDP_CDGPRIMARIA_LN
# PDM_2021mai_RDP:RDP_CMEPORTO_PL
# PDM_2021mai_RDP:RDP_RFOTICA_LN
# PDM_2021mai_RDP:RDP_PPFOTICA_PT
# PDM_4G_CC_CZP
# PDM_2021mai_RDP:RDP_UTPEREQUATIVAS_PL
# PDM_2021mai_RDP:RDP_ACBIOFISICAS_PL
# PDM_4H_CC_CZI
# PDM_2021mai_RDP:ZINCLUSIVO_PL2
# /Users/pedro.chaves/.pyenv/versions/3.10.0/lib/python3.10/site-packages/owslib/map/wms111.py:121: UserWarning: Content metadata for layer "PDM_2021mai_RDP:RDP_PONTES_LN" already exists. Using child layer
#   warnings.warn('Content metadata for layer "%s" already exists. Using child layer' % cm.id)
# /Users/pedro.chaves/.pyenv/versions/3.10.0/lib/python3.10/site-packages/owslib/map/wms111.py:121: UserWarning: Content metadata for layer "PDM_2021mai_RDP:RDP_AIPLANO_PL" already exists. Using child layer
#   warnings.warn('Content metadata for layer "%s" already exists. Using child layer' % cm.id)
# /Users/pedro.chaves/.pyenv/versions/3.10.0/lib/python3.10/site-packages/owslib/map/wms111.py:121: UserWarning: Content metadata for layer "PDM_2021mai_RDP:RDP_CIVPATRIMONIAL_PL" already exists. Using child layer
#   warnings.warn('Content metadata for layer "%s" already exists. Using child layer' % cm.id)
# /Users/pedro.chaves/.pyenv/versions/3.10.0/lib/python3.10/site-packages/owslib/map/wms111.py:121: UserWarning: Content metadata for layer "PDM_2021mai_RDP:vw_m_civpatrimonial_pl" already exists. Using child layer
#   warnings.warn('Content metadata for layer "%s" already exists. Using child layer' % cm.id)

# %%
len(wms.contents)
# Out:
# 136

# %%
# Latitude and longitude values
latitude = "41.14961"
longitude = "-8.61099"

# Nominatim reverse geocoding URL
reverse_geocode_url = "https://nominatim.openstreetmap.org/reverse"

# Define custom User-Agent
headers = {
    "User-Agent": "YourApplicationName/1.0 (mailto:your-email@example.com)"
}

# Parameters for the reverse search
params = {
    "lat": latitude,
    "lon": longitude,
    "format": "jsonv2"
}

# Make the request with the custom User-Agent
response = requests.get(reverse_geocode_url, params=params, headers=headers)

# Parse and print the response
location_data = response.json()
print(location_data)
# Out:
# {'place_id': 263788472, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 6540216044, 'lat': '41.149331', 'lon': '-8.6101404', 'category': 'amenity', 'type': 'library', 'place_rank': 30, 'importance': 7.251926451509908e-05, 'addresstype': 'amenity', 'name': 'Arquivo Geral Municipal', 'display_name': 'Arquivo Geral Municipal, 266, Praça do General Humberto Delgado, Baixa do Porto, Centro Histórico, Cedofeita, Santo Ildefonso, Sé, Miragaia, São Nicolau e Vitória, Porto, 4000-274, Portugal', 'address': {'amenity': 'Arquivo Geral Municipal', 'house_number': '266', 'road': 'Praça do General Humberto Delgado', 'neighbourhood': 'Baixa do Porto', 'suburb': 'Centro Histórico', 'city_district': 'Cedofeita, Santo Ildefonso, Sé, Miragaia, São Nicolau e Vitória', 'city': 'Porto', 'county': 'Porto', 'ISO3166-2-lvl6': 'PT-13', 'postcode': '4000-274', 'country': 'Portugal', 'country_code': 'pt'}, 'boundingbox': ['41.1492810', '41.1493810', '-8.6101904', '-8.6100904']}

# %%
import requests
import pandas as pd
from owslib.wms import WebMapService

# Connect to the WMS service
url = "https://geopdm.cm-porto.pt/services/pdm/wms"
wms = WebMapService(url, version='1.1.1')

# Geocoded coordinates (example coordinates from geocoding service)
lat = 41.1687404
lon = -8.6170212

# Define a margin (in degrees) for the bounding box
# Example: a small margin of 0.001 degree for a very localized query
margin = 0.001

# Calculate custom bounding box around the coordinate of interest
min_lon = lon - margin
max_lon = lon + margin
min_lat = lat - margin
max_lat = lat + margin

# Create the bounding box parameter
bbox_parameter = f"{min_lon},{min_lat},{max_lon},{max_lat}"

# WMS image dimensions
width = 800
height = 600

# List to store all properties data
all_properties = []

# Iterate through each layer in the service

for layer_name in wms.contents:
    layer_metadata = wms.contents[layer_name]
    
    # Retrieve the bounding box for each layer
    try:
        bounding_box = layer_metadata.boundingBoxWGS84  # WGS84 coordinates
    except AttributeError:
        print(f"No bounding box available for {layer_name}. Skipping.")
        continue
    
    min_lon, min_lat, max_lon, max_lat = bounding_box
    
    # Calculate the pixel coordinates (x, y) for each layer based on its bounding box
    if min_lon <= lon <= max_lon and min_lat <= lat <= max_lat:
        print(f"The point is within the bounding box of {layer_name}. Continuing.")
    else:
        print(f"The point is not within the bounding box of {layer_name}. Skipping.")
        continue
    

    # Use this bounding box in your WMS GetFeatureInfo request
    params = {
        "service": "WMS",
        "version": "1.1.1",
        "request": "GetFeatureInfo",
        "layers": layer_name,  # Use the current layer name
        "query_layers": layer_name,
        "bbox": bbox_parameter,
        "width": 800,  # Pixel width matching the new bounding box aspect ratio
        "height": 600,  # Pixel height matching the new bounding box aspect ratio
        "srs": "EPSG:4326",
        "x": 400,  # X coordinate in the middle of the image
        "y": 300,  # Y coordinate in the middle of the image
        "info_format": "application/json",
    }
    
    # Send the request and handle the response
    response = requests.get(url, params=params)
    
    try:
        response_data = response.json()
        
        # Iterate through features and collect properties
        for feature in response_data.get('features', []):
            all_properties.append(feature['properties'])
    except:
        print(f"Failed to fetch data for layer {layer_name}")

# Convert the collected properties into a DataFrame
df = pd.DataFrame(all_properties)
# Out:
# The point is within the bounding box of PDM_1A_PO_CQS. Continuing.
# The point is within the bounding box of PDM_2021mai_RDP:RDP_AIPLANO_PL. Continuing.
# Failed to fetch data for layer PDM_2021mai_RDP:RDP_AIPLANO_PL
# The point is within the bounding box of PDM_2021mai_RDP:RDP_QSFUNCIONAL_PL. Continuing.
# The point is within the bounding box of PDM_2021mai_RDP:RDP_QSOPERATIVA_PL. Continuing.
# The point is within the bounding box of PDM_2021mai_RDP:RDP_LINHAS_MERGE. Continuing.
# Failed to fetch data for layer PDM_2021mai_RDP:RDP_LINHAS_MERGE
# The point is not within the bounding box of PDM_2021mai_RDP:RDP_PONTES_LN. Skipping.
# The point is within the bounding box of PDM_2021mai_RDP:RDP_RPEDONAL_PL-NC1. Continuing.
# The point is within the bounding box of PDM_2021mai_RDP:RDP_CRODOVIARIOS_LN-Proposta. Continuing.
# The point is not within the bounding box of PDM_2021mai_RDP:RDP_AIPMPPORMENOR_PL. Skipping.
# The point is within the bounding box of PDM_2021mai_RDP:RDP_UOPGESTAO_PL. Continuing.
# The point is within the bounding box of PDM_1B_PO_CEEM. Continuing.
# The point is within the bounding box of PDM_2021mai_RDP:RDP_AVAPUBLICO_PL. Continuing.
# The point is within the bounding box of PDM_2021mai_RDP:RDP_AVEVECOLOGICO_PL. Continuing.
# The point is not within the bounding box of PDM_2021mai_RDP:RDP_AVAZSENSIVEIS_PL. Skipping.
# The point is within the bounding box of PDM_2021mai_RDP:RDP_RCONEXAO_PL. Continuing.
# The point is within the bounding box of PDM_2021mai_RDP:RDP_CVERDES_PL. Continuing.
# The point is within the bounding box of PDM_2021mai_RDP:RDP_AFARIBEIRINHA_PL. Continuing.
# The point is within the bounding box of PDM_2021mai_RDP:RDP_ALUVIAO_PL. Continuing.
# The point is not within the bounding box of PDM_2021mai_RDP:RDP_ADECLIVOSA_PL. Skipping.
# The point is within the bounding box of PDM_2021mai_RDP:RDP_LAGUA_LN. Continuing.
# The point is within the bounding box of PDM_2021mai_RDP:RDP_BRETENCAO_PT. Continuing.
# The point is not within the bounding box of PDM_2021mai_RDP:RDP_CECOLOGICO_PL. Skipping.
# The point is within the bounding box of PDM_2021mai_RDP:RDP_SRHOMOGENEAS_PL. Continuing.
# The point is within the bounding box of PDM_1C_PO_CRN_AA1. Continuing.
# The point is not within the bounding box of PDM_2021mai_RDP:AA1_APARTIFICIALIZADAS_PL. Skipping.
# The point is not within the bounding box of PDM_2021mai_RDP:AA1_ZMPROTECAO_PL. Skipping.
# The point is not within the bounding box of PDM_2021mai_RDP:AA1_ZTPROTECAO_PL. Skipping.
# The point is not within the bounding box of PDM_2021mai_RDP:AA1_FSGICOSTEIRA_PL. Skipping.
# The point is not within the bounding box of PDM_2021mai_RDP:AA1_FSECOSTEIRA_PL. Skipping.
# The point is not within the bounding box of PDM_2021mai_RDP:AA1_PIPMARITIMAS_LN. Skipping.
# The point is not within the bounding box of PDM_2021mai_RDP:AA1_TPRAIAS_PT. Skipping.
# The point is not within the bounding box of PDM_2021mai_RDP:AA1_MARGEM_PL. Skipping.
# The point is not within the bounding box of PDM_2021mai_RDP:AA1_APORTUARIA_LN. Skipping.
# The point is not within the bounding box of PDM_2021mai_RDP:AA1_LAIPOCCE_LN. Skipping.
# The point is within the bounding box of PDM_2021mai_RDP:AA1_ZIPINSTAVEL_PL. Continuing.
# The point is within the bounding box of PDM_2021mai_RDP:AA1_AINUNDAVEIS_PL. Continuing.
# The point is not within the bounding box of PDM_2021mai_RDP:AA1_NPISCATORIO_PT. Skipping.
# The point is not within the bounding box of PDM_2021mai_RDP:AA1_ACRITICAS_PL. Skipping.
# The point is within the bounding box of PDM_1D_PO_CZA. Continuing.
# The point is within the bounding box of PDM_2021mai_RDP:RDP_ZACUSTICO_PL. Continuing.
# The point is within the bounding box of PDM_1E_PO_CP1. Continuing.
# The point is within the bounding box of PDM_2021mai_RDP:RDP_AIUARQUITETONICO_PL. Continuing.
# The point is within the bounding box of PDM_2021mai_RDP:RDP_NLUGARES_PL. Continuing.
# The point is within the bounding box of PDM_2021mai_RDP:RDP_CIVPATRIMONIAL_PL. Continuing.
# The point is within the bounding box of PDM_2021mai_RDP:RDP_ZPICVCLASSIFICACAO_PL. Continuing.
# The point is within the bounding box of PDM_2021mai_RDP:RDP_ZNAEDIFICANDI_PL. Continuing.
# The point is within the bounding box of PDM_2021mai_RDP:RDP_ZPAAPUBLICO_PL. Continuing.
# The point is within the bounding box of PDM_2021mai_RDP:RDP_AAIPUBLICO_PT. Continuing.
# The point is not within the bounding box of PDM_2021mai_RDP:RDP_PNGCMFDOURO_PL. Skipping.
# The point is within the bounding box of PDM_1F_PO_CP2. Continuing.
# The point is within the bounding box of PDM_2021mai_RDP:RDP_ASARQUEOLOGICA_PL. Continuing.
# The point is within the bounding box of PDM_1G_PO_CEVE. Continuing.
# The point is not within the bounding box of PDM_2021mai_RDP:RDP_ZCPDLIMITADA_PL. Skipping.
# The point is within the bounding box of PDM_2021mai_RDP:RDP_AIEMETRO_PL. Continuing.
# The point is within the bounding box of PDM_2021mai_RDP:RDP_EMETRO_PT. Continuing.
# The point is within the bounding box of PDM_2021mai_RDP:RDP_CRODOVIARIOS_LN-dif-rua-prov-local_F9. Continuing.
# The point is within the bounding box of PDM_2021mai_RDP:RDP_CRODOVIARIOS_LN-dif-rua-prov-local_F8. Continuing.
# The point is within the bounding box of PDM_2021mai_RDP:RDP_CRODOVIARIOS_LN-dif-rua-prov-local_F7. Continuing.
# The point is within the bounding box of PDM_2021mai_RDP:RDP_CRODOVIARIOS_LN-dif-rua-prov-local_F6. Continuing.
# The point is within the bounding box of PDM_2021mai_RDP:RDP_CRODOVIARIOS_LN-dif-rua-prov-local_F5. Continuing.
# The point is not within the bounding box of PDM_2021mai_RDP:RDP_CRODOVIARIOS_LN-dif-rua-prov-local_F4. Skipping.
# The point is within the bounding box of PDM_2021mai_RDP:RDP_CRODOVIARIOS_LN-dif-rua-prov-local_F3. Continuing.
# The point is not within the bounding box of PDM_2021mai_RDP:RDP_CRODOVIARIOS_LN-dif-rua-prov-local_F2. Skipping.
# The point is within the bounding box of PDM_2021mai_RDP:RDP_CRODOVIARIOS_LN-dif-rua-prov-local_F1. Continuing.
# The point is within the bounding box of PDM_2B_PC_CPIF. Continuing.
# The point is not within the bounding box of PDM_2021mai_RDP:RDP_PIFLORESTAL-raw. Skipping.
# The point is within the bounding box of PDM_2C_PC_CCGD. Continuing.
# The point is within the bounding box of PDM_2021mai_RDP:mvw_m_zsaeronautica_pl. Continuing.
# The point is not within the bounding box of PDM_2021mai_RDP:mvw_m_pontes_ln. Skipping.
# The point is within the bounding box of PDM_2021mai_RDP:vw_m_civpatrimonial_pl. Continuing.
# The point is within the bounding box of PDM_2021mai_RDP:mvw_m_dpholagua_pl. Continuing.
# The point is not within the bounding box of PDM_2021mai_RDP:vw_m_mplavelocidade_pl. Skipping.
# The point is within the bounding box of PDM_2021mai_RDP:mvw_m_efprotegidas_pl. Continuing.
# The point is within the bounding box of PDM_2021mai_RDP:vw_m_zpaacvclassificacao_pl. Continuing.
# The point is within the bounding box of PDM_2021mai_RDP:mvw_m_zsreletrica_pl. Continuing.
# The point is within the bounding box of PDM_2021mai_RDP:mvw_m_zpepocipublico_pl. Continuing.
# The point is within the bounding box of PDM_2021mai_RDP:mvw_m_dnacional_pl. Continuing.
# The point is not within the bounding box of PDM_2021mai_RDP:mvw_m_zpetmenores_pl. Skipping.
# The point is within the bounding box of PDM_2021mai_RDP:mvw_m_rrnedesclassificadas_pl. Continuing.
# The point is within the bounding box of PDM_2021mai_RDP:mvw_m_ideeletrica_ln. Continuing.
# The point is not within the bounding box of PDM_2021mai_RDP:mvw_m_iteeletrica_ln. Skipping.
# The point is not within the bounding box of PDM_2021mai_RDP:mvw_m_oleoduto_ln. Skipping.
# The point is within the bounding box of PDM_2021mai_RDP:mvw_m_margem_ln. Continuing.
# The point is within the bounding box of PDM_2021mai_RDP:mvw_m_fpesada_ln. Continuing.
# The point is not within the bounding box of PDM_2021mai_RDP:mvw_m_dpferroviario_pl. Skipping.
# The point is within the bounding box of PDM_2021mai_RDP:mvw_m_dphidrico_ln. Continuing.
# The point is within the bounding box of PDM_2021mai_RDP:mvw_m_zpicvclassificacao_pl. Continuing.
# The point is within the bounding box of PDM_2021mai_RDP:mvw_m_znaedificandi_pl. Continuing.
# The point is within the bounding box of PDM_2021mai_RDP:mvw_m_itreletrica_pt. Continuing.
# The point is within the bounding box of PDM_2021mai_RDP:vw_m_aacvclassificacao_pt. Continuing.
# The point is not within the bounding box of PDM_2021mai_RDP:mvw_m_fosmaritimo_pt. Skipping.
# The point is not within the bounding box of PDM_2021mai_RDP:mvw_m_zssmaritima_pl. Skipping.
# The point is within the bounding box of PDM_2021mai_RDP:mvw_m_mgeodesicos_pt. Continuing.
# The point is within the bounding box of PDM_2021mai_RDP:mvw_m_zprgeodesica_pl. Continuing.
# The point is not within the bounding box of PDM_2021mai_RDP:mvw_m_zsaagua_pl. Skipping.
# The point is not within the bounding box of PDM_2021mai_RDP:vw_m_gfdouro_pl. Skipping.
# The point is within the bounding box of PDM_4A_CC_CAEC. Continuing.
# The point is within the bounding box of PDM_2021mai_RDP:RDP_AECOLETIVOS_PL. Continuing.
# The point is within the bounding box of PDM_4B_CC_CITC. Continuing.
# The point is within the bounding box of PDM_2021mai_RDP:RDP_INTERFACES_PT. Continuing.
# The point is within the bounding box of PDM_2021mai_RDP:RDP_CAUTOCARRO_PL. Continuing.
# The point is within the bounding box of PDM_2021mai_RDP:RDP_FULTRALIGEIRA_LN. Continuing.
# The point is within the bounding box of PDM_2021mai_RDP:RDP_FPESADA_LN_CC4B_CITC. Continuing.
# The point is within the bounding box of PDM_2021mai_RDP:RDP_PDISSUASORES_PT. Continuing.
# The point is within the bounding box of PDM_2021mai_RDP:RDP_FLIGEIRA_LN. Continuing.
# The point is not within the bounding box of PDM_2021mai_RDP:RDP_LBRT_LN. Skipping.
# The point is within the bounding box of PDM_2021mai_RDP:RDP_EMETRO_PT_CC4B. Continuing.
# The point is within the bounding box of PDM_4C_CC_CIMS. Continuing.
# The point is not within the bounding box of PDM_2021mai_RDP:RDP_ZXXI_PL. Skipping.
# The point is within the bounding box of PDM_2021mai_RDP:RDP_RPEDONAL_PL. Continuing.
# The point is within the bounding box of PDM_2021mai_RDP:RDP_RCESTRUTURANTE_PL. Continuing.
# The point is not within the bounding box of PDM_2021mai_RDP:RDP_IPBICI_LN. Skipping.
# The point is within the bounding box of PDM_4D_CC_CI1. Continuing.
# The point is not within the bounding box of PDM_2021mai_RDP:RDP_ETARS_PL. Skipping.
# The point is not within the bounding box of PDM_2021mai_RDP:RDP_CTLAREUTILIZACAO_LN. Skipping.
# The point is within the bounding box of PDM_2021mai_RDP:RDP_CGIEMISSARIOS_LN. Continuing.
# The point is within the bounding box of PDM_2021mai_RDP:RDP_RESERVATORIOS_PL. Continuing.
# The point is within the bounding box of PDM_2021mai_RDP:RDP_CADUTORAS_ADP_LN. Continuing.
# The point is within the bounding box of PDM_2021mai_RDP:RDP_CADUTORAS_ADDP_LN. Continuing.
# The point is within the bounding box of PDM_2021mai_RDP:RDP_PECADUTORAS_ADDP_PT. Continuing.
# The point is within the bounding box of PDM_4E_CC_CI2. Continuing.
# The point is within the bounding box of PDM_2021mai_RDP:RDP_ITRELETRICA_PL. Continuing.
# The point is within the bounding box of PDM_2021mai_RDP:RDP_IDEELETRICA_LN_CC4E. Continuing.
# The point is not within the bounding box of PDM_2021mai_RDP:RDP_ITEELETRICA_LN_CC4E. Skipping.
# The point is within the bounding box of PDM_4F_CC_CI3. Continuing.
# The point is within the bounding box of PDM_2021mai_RDP:RDP_ECOCENTROS_PL. Continuing.
# The point is not within the bounding box of PDM_2021mai_RDP:RDP_OLEODUTO_LN. Skipping.
# The point is within the bounding box of PDM_2021mai_RDP:RDP_CDGPRIMARIA_LN. Continuing.
# The point is not within the bounding box of PDM_2021mai_RDP:RDP_CMEPORTO_PL. Skipping.
# The point is within the bounding box of PDM_2021mai_RDP:RDP_RFOTICA_LN. Continuing.
# The point is within the bounding box of PDM_2021mai_RDP:RDP_PPFOTICA_PT. Continuing.
# The point is within the bounding box of PDM_4G_CC_CZP. Continuing.
# The point is within the bounding box of PDM_2021mai_RDP:RDP_UTPEREQUATIVAS_PL. Continuing.
# The point is within the bounding box of PDM_2021mai_RDP:RDP_ACBIOFISICAS_PL. Continuing.
# The point is within the bounding box of PDM_4H_CC_CZI. Continuing.
# The point is not within the bounding box of PDM_2021mai_RDP:ZINCLUSIVO_PL2. Skipping.

# %%
all_properties
# Out:
# [{'uuid': 'b61bb64c-2f0b-4d7b-aec8-20f3489de0b9',
#   'tema_po': 'Qualificação do solo funcional',
#   'obs_c_espaco': 'Espaços centrais',
#   'obs_sc_espaco': 'Área de frente urbana contínua do tipo II',
#   'id_objeto': 'b61bb64c-2f0b-4d7b-aec8-20f3489de0b9'},
#  {'uuid': 'b61bb64c-2f0b-4d7b-aec8-20f3489de0b9',
#   'tema_po': 'Qualificação do solo funcional',
#   'obs_c_espaco': 'Espaços centrais',
#   'obs_sc_espaco': 'Área de frente urbana contínua do tipo II',
#   'id_objeto': 'b61bb64c-2f0b-4d7b-aec8-20f3489de0b9'},
#  {'uuid': '4b6d8f7e-15ed-4ba9-9745-deb35438c66f',
#   'tema_po': ' Qualificação do solo operativa',
#   'obs_t_espaco': 'Espaço consolidado',
#   'id_objeto': '4b6d8f7e-15ed-4ba9-9745-deb35438c66f'},
#  {'uuid': '728ea325-3983-4aa1-a2e8-01c10c57c65d',
#   'subtema_po': 'Corredores verdes',
#   'tipologia': 'Corredor verde complementar',
#   'designaç': 'Corredor Verde da Granja (Constituição / Regado)',
#   'id_objeto': '728ea325-3983-4aa1-a2e8-01c10c57c65d'},
#  {'uuid': '728ea325-3983-4aa1-a2e8-01c10c57c65d',
#   'subtema_po': 'Corredores verdes',
#   'tipologia': 'Corredor verde complementar',
#   'designaç': 'Corredor Verde da Granja (Constituição / Regado)',
#   'id_objeto': '728ea325-3983-4aa1-a2e8-01c10c57c65d'},
#  {'uuid': '3c7c9d1f-1361-4ada-bb60-6a083f1c8901',
#   'subtema_po': 'Área de Aluvião',
#   'id_objeto': '3c7c9d1f-1361-4ada-bb60-6a083f1c8901'},
#  {'uuid': 'bfa167fd-4a3c-48e4-818a-fdfed4566b18',
#   'subtema_po': 'Sub-regiões homogéneas',
#   'srh': 'Grande Porto',
#   'id_objeto': 'bfa167fd-4a3c-48e4-818a-fdfed4566b18'},
#  {'uuid': '17415b73-962d-4b97-a07f-ff0dbc95903b',
#   'subtema_po': 'Zonamento acústico',
#   'tipo_za': 'Zona mista',
#   'id_objeto': '17415b73-962d-4b97-a07f-ff0dbc95903b'},
#  {'uuid': '17415b73-962d-4b97-a07f-ff0dbc95903b',
#   'subtema_po': 'Zonamento acústico',
#   'tipo_za': 'Zona mista',
#   'id_objeto': '17415b73-962d-4b97-a07f-ff0dbc95903b'},
#  {'uuid': '903d50fd-58b2-4874-9d35-a275b14bc715',
#   'classificacao': 'Zona 7',
#   'legislacao_aplicavel': 'Dec-Lei nº 45987 de 22/10/1964; Dec. Regulamentar nº 7/83 de 3 de fevereiro, DR, 1ª série, nº 28 com a Declaração Pres.Cons.Minis. de 9/2/83, DR, 1ª série-3º sup, nº 48 de 28 de fevereiro',
#   'etiqueta': '7',
#   'id_objeto': '903d50fd-58b2-4874-9d35-a275b14bc715'},
#  {'uuid': '903d50fd-58b2-4874-9d35-a275b14bc715',
#   'classificacao': 'Zona 7',
#   'legislacao_aplicavel': 'Dec-Lei nº 45987 de 22/10/1964; Dec. Regulamentar nº 7/83 de 3 de fevereiro, DR, 1ª série, nº 28 com a Declaração Pres.Cons.Minis. de 9/2/83, DR, 1ª série-3º sup, nº 48 de 28 de fevereiro',
#   'etiqueta': '7',
#   'id_objeto': '903d50fd-58b2-4874-9d35-a275b14bc715'},
#  {'uuid': '8d3b987f-4308-44f1-b483-c6440b8ebf20',
#   'tipologia': 'Rede elétrica de alta tensão (60kV) - RND',
#   'largura_servidao': '25 metros',
#   'legislacao_aplicavel': 'Decreto Regulamentar n.º 1/92, D.R. n.º 41, Série I-B de 18/02',
#   'id_objeto': '8d3b987f-4308-44f1-b483-c6440b8ebf20'},
#  {'uuid': 'cbca2a33-b951-49e8-9b6a-0d81352545c0',
#   'tipologia': 'Rede elétrica de alta tensão (60 KV) - RND',
#   'localizacao': 'subterrânea',
#   'legislacao_aplicavel': 'Decreto Regulamentar n.º 1/92, D.R. n.º 41, série I-B de 18/02',
#   'situacao_inicial': 'existente',
#   'id_objeto': 'cbca2a33-b951-49e8-9b6a-0d81352545c0'},
#  {'uuid': 'dc261605-dae8-4c65-b740-6076b1a18213',
#   'subtema_cc': 'Rede elétrica de alta tensão e média tensão',
#   'obs': 'Rede nacional distribuição de eletricidade (RND)',
#   'tipologia': 'Alta tensão',
#   'local': 'subterrânea',
#   'situacao': 'existente',
#   'id_objeto': 'dc261605-dae8-4c65-b740-6076b1a18213'},
#  {'uuid': 'dc261605-dae8-4c65-b740-6076b1a18213',
#   'subtema_cc': 'Rede elétrica de alta tensão e média tensão',
#   'obs': 'Rede nacional distribuição de eletricidade (RND)',
#   'tipologia': 'Alta tensão',
#   'local': 'subterrânea',
#   'situacao': 'existente',
#   'id_objeto': 'dc261605-dae8-4c65-b740-6076b1a18213'},
#  {'uuid': '47133254-0c45-4a8b-82f8-2a0946f572ee',
#   'tema_cc': 'Unidades territoriais perequativas',
#   'desig': 'Área Central',
#   'id_objeto': '47133254-0c45-4a8b-82f8-2a0946f572ee'},
#  {'uuid': '47133254-0c45-4a8b-82f8-2a0946f572ee',
#   'tema_cc': 'Unidades territoriais perequativas',
#   'desig': 'Área Central',
#   'id_objeto': '47133254-0c45-4a8b-82f8-2a0946f572ee'}]

# %%
feature['properties']
# Out:
# {'uuid': '4b6d8f7e-15ed-4ba9-9745-deb35438c66f',
#  'tema_po': ' Qualificação do solo operativa',
#  'obs_t_espaco': 'Espaço consolidado',
#  'id_objeto': '4b6d8f7e-15ed-4ba9-9745-deb35438c66f'}

# %%
import requests
from PIL import Image
from io import BytesIO
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from owslib.wms import WebMapService

# Connection parameters
url = "https://geopdm.cm-porto.pt/services/pdm/wms"
layer_name = "PDM_2021mai_RDP:RDP_QSFUNCIONAL_PL"

# House geocoded coordinates
latitude = 41.1687404
longitude = -8.6170212
margin = 0.001  # Define a small margin

# Bounding box around the house coordinates
min_lon = longitude - margin
max_lon = longitude + margin
min_lat = latitude - margin
max_lat = latitude + margin

# Connect to WMS service
wms = WebMapService(url, version='1.1.1')
layer_metadata = wms.contents[layer_name]

# Layer bounding box (use it if it encompasses your area of interest)
layer_bbox = layer_metadata.boundingBoxWGS84  # WGS84 coordinates

# For visualization, use the layer bounding box; adjust if needed
bbox = ",".join(map(str, layer_bbox))

# WMS GetMap request parameters
params = {
    "service": "WMS",
    "version": "1.1.1",
    "request": "GetMap",
    "layers": layer_name,
    "styles": "",  # Use default layer style
    "bbox": bbox,  # Layer bounding box
    "width": 800,  # Width of image in pixels
    "height": 600,  # Height of image in pixels
    "srs": "EPSG:4326",
    "format": "image/png"
}

# Get the map image
response = requests.get(url, params=params)
img = Image.open(BytesIO(response.content))

# Plot the image and overlay the bounding box
fig, ax = plt.subplots(figsize=(10, 8))
ax.imshow(img)

# Calculate pixel rectangle for bounding box
rect_x = (min_lon - layer_bbox[0]) / (layer_bbox[2] - layer_bbox[0]) * 800
rect_y = (layer_bbox[3] - max_lat) / (layer_bbox[3] - layer_bbox[1]) * 600
rect_width = (max_lon - min_lon) / (layer_bbox[2] - layer_bbox[0]) * 800
rect_height = (max_lat - min_lat) / (layer_bbox[3] - layer_bbox[1]) * 600

# Draw the bounding box
rect = patches.Rectangle((rect_x, rect_y), rect_width, rect_height, linewidth=2, edgecolor='red', facecolor='none')
ax.add_patch(rect)

plt.title("Map with Bounding Box around Point of Interest")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.show()
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/owslib/map/wms111.py:121: UserWarning: Content metadata for layer "PDM_2021mai_RDP:RDP_PONTES_LN" already exists. Using child layer
#   warnings.warn('Content metadata for layer "%s" already exists. Using child layer' % cm.id)
# /opt/anaconda3/lib/python3.12/site-packages/owslib/map/wms111.py:121: UserWarning: Content metadata for layer "PDM_2021mai_RDP:RDP_AIPLANO_PL" already exists. Using child layer
#   warnings.warn('Content metadata for layer "%s" already exists. Using child layer' % cm.id)
# /opt/anaconda3/lib/python3.12/site-packages/owslib/map/wms111.py:121: UserWarning: Content metadata for layer "PDM_2021mai_RDP:RDP_CIVPATRIMONIAL_PL" already exists. Using child layer
#   warnings.warn('Content metadata for layer "%s" already exists. Using child layer' % cm.id)
# /opt/anaconda3/lib/python3.12/site-packages/owslib/map/wms111.py:121: UserWarning: Content metadata for layer "PDM_2021mai_RDP:vw_m_civpatrimonial_pl" already exists. Using child layer
#   warnings.warn('Content metadata for layer "%s" already exists. Using child layer' % cm.id)

# %%
from backend.helpers.chunker import PDFChunker

# %%
pdf_path = "backend/data/PDM_Porto_Aviso n.º 1934_2023.pdf"
chunker = PDFChunker(pdf_path)

# %%
chunks = chunker.split_pdf_by_sections("SECÇÃO")

# %%
len(chunks)
# Out:
# 25

# %%
wms = WebMapService("https://geopdm.cm-porto.pt/services/pdm/wms", version="1.1.1")

layer = wms.contents[layer_name]
layer_info = {
    "keywords": layer.keywords,
    "title": layer.title,
    "name": layer.name,
    "boundingBoxWGS84": layer.boundingBoxWGS84,
}
print(layer_info)
# Out:
# {'keywords': ['features', 'ZINCLUSIVO_PL2'], 'title': 'Zonamento inclusivo', 'name': 'PDM_2021mai_RDP:ZINCLUSIVO_PL2', 'boundingBoxWGS84': (-8.633068618203888, 41.13960476925284, -8.589452839535474, 41.156732878345515)}
# /Users/pedro.chaves/.pyenv/versions/3.10.0/lib/python3.10/site-packages/owslib/map/wms111.py:121: UserWarning: Content metadata for layer "PDM_2021mai_RDP:RDP_PONTES_LN" already exists. Using child layer
#   warnings.warn('Content metadata for layer "%s" already exists. Using child layer' % cm.id)
# /Users/pedro.chaves/.pyenv/versions/3.10.0/lib/python3.10/site-packages/owslib/map/wms111.py:121: UserWarning: Content metadata for layer "PDM_2021mai_RDP:RDP_AIPLANO_PL" already exists. Using child layer
#   warnings.warn('Content metadata for layer "%s" already exists. Using child layer' % cm.id)
# /Users/pedro.chaves/.pyenv/versions/3.10.0/lib/python3.10/site-packages/owslib/map/wms111.py:121: UserWarning: Content metadata for layer "PDM_2021mai_RDP:RDP_CIVPATRIMONIAL_PL" already exists. Using child layer
#   warnings.warn('Content metadata for layer "%s" already exists. Using child layer' % cm.id)
# /Users/pedro.chaves/.pyenv/versions/3.10.0/lib/python3.10/site-packages/owslib/map/wms111.py:121: UserWarning: Content metadata for layer "PDM_2021mai_RDP:vw_m_civpatrimonial_pl" already exists. Using child layer
#   warnings.warn('Content metadata for layer "%s" already exists. Using child layer' % cm.id)
